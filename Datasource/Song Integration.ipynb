# %%
# !pip install pandas
# Out:
# ...
#      --------------------------------------- 10.7/10.7 MB 18.7 MB/s eta 0:00:00
# ...
#      ------------------------------------- 341.8/341.8 kB 22.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 15.8/15.8 MB 73.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
mssheet = pd.read_csv("C:\\Users\\lynni\\Downloads\\archive\\song_lyrics.csv")

# %%
mssheet.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3  \
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1            en
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3            en
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4            en
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5            en
# ...

# %%
mssheet[mssheet.year >= 2022].shape[0]
mssheet[mssheet.title == "วาฬเกยตื้น"]
# check row default
count_row = mssheet.shape[0]
count_row
# Out:
# 116841

# %%
mssheet = mssheet[mssheet.year >= 2022]
mssheet
# Out:
#                title      tag             artist  year  views features  \
# 83027    She Love It       rb           RUSSELL!  2022    783       {}
# 157515   The Breathe     rock       Dan Burnette  2022     24       {}
# 161090       Nouveau     rock       Dan Burnette  2022     50       {}
# 170458       Talk It      rap            Ballout  2022   3188       {}
# 253706     Loveology     rock     Regina Spektor  2022   5795       {}
# ...              ...      ...                ...   ...    ...      ...
# 5134848       ZOMBIE      rap        Antropolita  2022      1       {}
# 5134851        Ocean      pop            Effemar  2022      3       {}
# 5134852      64 Bars      rap             Rapido  2022      4       {}
# 5134854          CEO      rap        Antropolita  2022      5       {}
# 5134855   New Number  country  Alana Springsteen  2022      1       {}
#
#                                                     lyrics       id  \
# ...

# %%
mssheet = mssheet.sample(n=300)
nmsheet = mssheet.iloc[:300]
# Check row after delete
# count_row_new = nmsheet.shape[0]
# count_row_new
nmsheet
# Out:
#                             title      tag         artist  year  views  \
# 5062782       Perdiendo La Noción      pop  Playboy Buzzy  2022      4
# 5129722  Di Bawah Jembatan Kuning  country    Jason Ranti  2022      5
# 5045381        Immaculate Friends     rock            Ten  2022     35
# 4955515                   No Hook      rap          9K900  2022     14
# 5014473                Bugs bunny      rap       Yngdaddy  2022     23
# ...                           ...      ...            ...   ...    ...
# 5034751          Sweather Weather      pop       Remzcore  2022    157
# 5098987                 Parasitic     rock         Arsine  2022      2
# 5116578                  Kawasaki      rap      Stef Cash  2022      7
# 5035173                Yok Saydın      pop     Yedinci Ev  2022     20
# 5088020                   Changes      rap      New Brand  2022      4
#
#           features                                             lyrics  \
# ...

# %%
# nmsheet = nmsheet.drop(['id', 'language_cld3', 'language_ft', 'views'], axis=1)
nmsheet = nmsheet.drop(['language_cld3', 'language_ft'], axis=1)

# %%
nmsheet['features'] = nmsheet['features'].str.replace(r'[{"}]', '', regex=True)
nmsheet['features'] = nmsheet['features'].str.replace(r'[\\]', '', regex=True)
nmsheet['lyrics'] = nmsheet['lyrics'].str.replace(r'\[.*\]', '', regex=True)
nmsheet['lyrics'] = nmsheet['lyrics'].str.replace('\n', ' ', regex=True)

# nmsheet['features'] = nmsheet['features'].str.replace(r'[{"}]', '', regex=True)
#nmsheet.loc[:, 'features'] = nmsheet['features'].str.replace(r'[{"}]', '', regex=True)
#nmsheet.loc[:, 'features'] = nmsheet.loc[:, 'features'].str.replace(r'[\\]', '', regex=True)
#nmsheet.loc[:, 'lyrics'] = nmsheet.loc[:, 'lyrics'].str.replace(r'\[.*\]', '', regex=True)
#nmsheet.loc[:, 'lyrics'] = nmsheet.loc[:, 'lyrics'].str.replace('\n', ' ', regex=True)

# %%
nmsheet
# Out:
#                             title      tag         artist  year  views  \
# 5062782       Perdiendo La Noción      pop  Playboy Buzzy  2022      4
# 5129722  Di Bawah Jembatan Kuning  country    Jason Ranti  2022      5
# 5045381        Immaculate Friends     rock            Ten  2022     35
# 4955515                   No Hook      rap          9K900  2022     14
# 5014473                Bugs bunny      rap       Yngdaddy  2022     23
# ...                           ...      ...            ...   ...    ...
# 5034751          Sweather Weather      pop       Remzcore  2022    157
# 5098987                 Parasitic     rock         Arsine  2022      2
# 5116578                  Kawasaki      rap      Stef Cash  2022      7
# 5035173                Yok Saydın      pop     Yedinci Ev  2022     20
# 5088020                   Changes      rap      New Brand  2022      4
#
#         features                                             lyrics       id  \
# ...

# %%
nmsheet[nmsheet.language == "th"]
# Out:
#                  title  tag     artist  year  views features  \
# 5098200  Ready or Not?  pop  Pretzelle  2022      6
#
#                                                     lyrics       id language
# 5098200  Hi, everyone, it's a PRETZELLE day Let's play ...  7811931       th

# %%
nmsheet.to_csv('/Output/out.csv', index=False)
#nmsheet.to_json('out.json', orient="")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# e:\Elastic\Datasource\Song Integration.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Elastic/Datasource/Song%20Integration.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> nmsheet.to_csv('out/out.csv', index=False)
#
# File c:\Users\lynni\anaconda3\lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
# ...

# %%
nmsheet.sample(n=1)
# Out:
#                    title  tag   artist  year features  \
# 3467078  Торнадо Tornado  rap  96train  2022    Potya
#
#                                                     lyrics language
# 3467078   Yeah,yeah Ты вертишься как торнадо Потому что...       ru
